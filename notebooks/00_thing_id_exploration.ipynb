# %%
import json
from pathlib import Path

# %%
td_dir = Path("../../../datasets/ForeSight/household-1235/thing_descriptions/")

# %%
for i, td in enumerate(td_dir.iterdir()):
    with open (td, "r") as td_stream:
        td_dict = json.load(td_stream)
    if "@type" in td_dict and "iot:PowerMonitoring" in td_dict["@type"]:
        print(i, td_dict["title"])
        # print(td_dict["@type"])
        print(td_dict["id"])
        print("")
# Out:
# 2 Smart Switch 6 Arbeitszimmer Keller 1
# uri:urn:a027dea8-227a-4a31-9409-6bac722fff90
#
# 3 DECT200 Arbeitszimmer EG
# uri:urn:c28f5a50e1234e8a
#
# 13 Smart Switch 6 Wasserkocher
# uri:urn:b7714883-b707-464b-9f34-3caba159b317
#
# 18 DECT200 Badezimmer Keller Steckdose
# uri:urn:66539b2be9194db9
#
# 20 DECT200 Kühlschrank Keller
# uri:urn:82350c928bc644b4
#
# 21 Smart Switch 6 Kaffeemaschine
# uri:urn:5463174b-d705-4713-8b3c-dac8974ae0c1
#
# 22 Smart Switch 6 Arbeitszimmer Keller Lautsprecher
# uri:urn:6737a4fb-9757-4c5d-afff-fad005ae278c
#
# 23 Smart Switch 6 Bügeln Staubsaugen
# uri:urn:4c59e1c9-c7b8-475b-b7a9-bc61d9da5180
#
# 25 Herdplatten - Modbus
# uri:urn:d404d877-f5bf-454b-8584-ef255ce2bc62
#
# 28 eHz
# uri:urn:554b7c6c19254be5
#
# 30 DECT200 Bügeln Staubsaugen
# uri:urn:c87d04be65524bd1
#
# 31 DECT200 Kaffeemaschine
# uri:urn:337d97897d78463c
#
# 35 Dect200Wasserkocher
# uri:urn:5922edb6a8264e56
#
# 37 Wohnzimmer Smart Switch 6
# uri:urn:8303a6a0-9fde-4cc6-ba24-84b7a84ffca6
# ...

# %%
{
    "38 DECT210 Waschmaschine":
    "uri:urn:6a112240-117e-4ec3-a129-5bc90908aedb",
    
    "46 Smart Switch 6 Spülmaschine":
    "uri:urn:e91f9319-71af-4ddb-ab7d-fb47b45d69ad",
    
    # "53 Smart Switch 6 Thermomix":
    # "uri:urn:5b59894b-805d-4d7c-96c9-8ab42a18c3c7",
    
    "67 DECT200 Waschmaschine":
    "uri:urn:4b29c04c920141e8",
    
    "86 DECT200 Spülmaschine":
    "uri:urn:cc256ae649904024",
}
# Out:
# {'38 DECT210 Waschmaschine': 'uri:urn:6a112240-117e-4ec3-a129-5bc90908aedb',
#  '46 Smart Switch 6 Spülmaschine': 'uri:urn:e91f9319-71af-4ddb-ab7d-fb47b45d69ad',
#  '67 DECT200 Waschmaschine': 'uri:urn:4b29c04c920141e8',
#  '86 DECT200 Spülmaschine': 'uri:urn:cc256ae649904024'}
