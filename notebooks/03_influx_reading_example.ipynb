# %%
import pandas as pd

# %%
from os import environ

from dotenv import load_dotenv
import influxdb_client


bucket = "homeassist"
org = "homeassist"
url = "http://localhost:8086"

load_dotenv()
token = environ["INFLUXDB_TOKEN"]


client = influxdb_client.InfluxDBClient(url=url, token=token, org=org)
query_api = client.query_api()

query = """from(bucket: "homeassist")
  |> range(start: -2d)
  |> filter(fn: (r) => r["_measurement"] == "°C")
  |> filter(fn: (r) => r["_field"] == "value")"""
tables = query_api.query(query, org=org)


for table in tables:
    for record in table.records:
        print(record)
# Out:
# FluxRecord() table: 0, {'result': '_result', 'table': 0, '_start': datetime.datetime(2025, 6, 28, 7, 53, 11, 376450, tzinfo=tzutc()), '_stop': datetime.datetime(2025, 6, 30, 7, 53, 11, 376450, tzinfo=tzutc()), '_time': datetime.datetime(2025, 6, 28, 8, 33, 28, 947097, tzinfo=tzutc()), '_value': 26.2, '_field': 'value', '_measurement': '°C', 'domain': 'sensor', 'entity_id': 'thermometer_hygrometer_temperature'}
# FluxRecord() table: 0, {'result': '_result', 'table': 0, '_start': datetime.datetime(2025, 6, 28, 7, 53, 11, 376450, tzinfo=tzutc()), '_stop': datetime.datetime(2025, 6, 30, 7, 53, 11, 376450, tzinfo=tzutc()), '_time': datetime.datetime(2025, 6, 28, 9, 21, 16, 250971, tzinfo=tzutc()), '_value': 26.4, '_field': 'value', '_measurement': '°C', 'domain': 'sensor', 'entity_id': 'thermometer_hygrometer_temperature'}
# FluxRecord() table: 0, {'result': '_result', 'table': 0, '_start': datetime.datetime(2025, 6, 28, 7, 53, 11, 376450, tzinfo=tzutc()), '_stop': datetime.datetime(2025, 6, 30, 7, 53, 11, 376450, tzinfo=tzutc()), '_time': datetime.datetime(2025, 6, 28, 9, 57, 6, 668208, tzinfo=tzutc()), '_value': 26.6, '_field': 'value', '_measurement': '°C', 'domain': 'sensor', 'entity_id': 'thermometer_hygrometer_temperature'}
# FluxRecord() table: 0, {'result': '_result', 'table': 0, '_start': datetime.datetime(2025, 6, 28, 7, 53, 11, 376450, tzinfo=tzutc()), '_stop': datetime.datetime(2025, 6, 30, 7, 53, 11, 376450, tzinfo=tzutc()), '_time': datetime.datetime(2025, 6, 28, 10, 40, 54, 948764, tzinfo=tzutc()), '_value': 26.8, '_field': 'value', '_measurement': '°C', 'domain': 'sensor', 'entity_id': 'thermometer_hygrometer_temperature'}
# FluxRecord() table: 0, {'result': '_result', 'table': 0, '_start': datetime.datetime(2025, 6, 28, 7, 53, 11, 376450, tzinfo=tzutc()), '_stop': datetime.datetime(2025, 6, 30, 7, 53, 11, 376450, tzinfo=tzutc()), '_time': datetime.datetime(2025, 6, 28, 11, 36, 39, 972910, tzinfo=tzutc()), '_value': 27.0, '_field': 'value', '_measurement': '°C', 'domain': 'sensor', 'entity_id': 'thermometer_hygrometer_temperature'}
# FluxRecord() table: 0, {'result': '_result', 'table': 0, '_start': datetime.datetime(2025, 6, 28, 7, 53, 11, 376450, tzinfo=tzutc()), '_stop': datetime.datetime(2025, 6, 30, 7, 53, 11, 376450, tzinfo=tzutc()), '_time': datetime.datetime(2025, 6, 28, 13, 0, 17, 441370, tzinfo=tzutc()), '_value': 27.2, '_field': 'value', '_measurement': '°C', 'domain': 'sensor', 'entity_id': 'thermometer_hygrometer_temperature'}
# FluxRecord() table: 0, {'result': '_result', 'table': 0, '_start': datetime.datetime(2025, 6, 28, 7, 53, 11, 376450, tzinfo=tzutc()), '_stop': datetime.datetime(2025, 6, 30, 7, 53, 11, 376450, tzinfo=tzutc()), '_time': datetime.datetime(2025, 6, 28, 19, 8, 37, 792993, tzinfo=tzutc()), '_value': 27.0, '_field': 'value', '_measurement': '°C', 'domain': 'sensor', 'entity_id': 'thermometer_hygrometer_temperature'}
# FluxRecord() table: 0, {'result': '_result', 'table': 0, '_start': datetime.datetime(2025, 6, 28, 7, 53, 11, 376450, tzinfo=tzutc()), '_stop': datetime.datetime(2025, 6, 30, 7, 53, 11, 376450, tzinfo=tzutc()), '_time': datetime.datetime(2025, 6, 28, 20, 26, 16, 800382, tzinfo=tzutc()), '_value': 26.8, '_field': 'value', '_measurement': '°C', 'domain': 'sensor', 'entity_id': 'thermometer_hygrometer_temperature'}
# FluxRecord() table: 0, {'result': '_result', 'table': 0, '_start': datetime.datetime(2025, 6, 28, 7, 53, 11, 376450, tzinfo=tzutc()), '_stop': datetime.datetime(2025, 6, 30, 7, 53, 11, 376450, tzinfo=tzutc()), '_time': datetime.datetime(2025, 6, 28, 21, 53, 53, 134716, tzinfo=tzutc()), '_value': 26.6, '_field': 'value', '_measurement': '°C', 'domain': 'sensor', 'entity_id': 'thermometer_hygrometer_temperature'}
# FluxRecord() table: 0, {'result': '_result', 'table': 0, '_start': datetime.datetime(2025, 6, 28, 7, 53, 11, 376450, tzinfo=tzutc()), '_stop': datetime.datetime(2025, 6, 30, 7, 53, 11, 376450, tzinfo=tzutc()), '_time': datetime.datetime(2025, 6, 28, 23, 43, 23, 723658, tzinfo=tzutc()), '_value': 26.4, '_field': 'value', '_measurement': '°C', 'domain': 'sensor', 'entity_id': 'thermometer_hygrometer_temperature'}
# FluxRecord() table: 0, {'result': '_result', 'table': 0, '_start': datetime.datetime(2025, 6, 28, 7, 53, 11, 376450, tzinfo=tzutc()), '_stop': datetime.datetime(2025, 6, 30, 7, 53, 11, 376450, tzinfo=tzutc()), '_time': datetime.datetime(2025, 6, 29, 1, 40, 52, 269078, tzinfo=tzutc()), '_value': 26.2, '_field': 'value', '_measurement': '°C', 'domain': 'sensor', 'entity_id': 'thermometer_hygrometer_temperature'}
# FluxRecord() table: 0, {'result': '_result', 'table': 0, '_start': datetime.datetime(2025, 6, 28, 7, 53, 11, 376450, tzinfo=tzutc()), '_stop': datetime.datetime(2025, 6, 30, 7, 53, 11, 376450, tzinfo=tzutc()), '_time': datetime.datetime(2025, 6, 29, 3, 42, 19, 911229, tzinfo=tzutc()), '_value': 26.0, '_field': 'value', '_measurement': '°C', 'domain': 'sensor', 'entity_id': 'thermometer_hygrometer_temperature'}
# FluxRecord() table: 0, {'result': '_result', 'table': 0, '_start': datetime.datetime(2025, 6, 28, 7, 53, 11, 376450, tzinfo=tzutc()), '_stop': datetime.datetime(2025, 6, 30, 7, 53, 11, 376450, tzinfo=tzutc()), '_time': datetime.datetime(2025, 6, 29, 6, 43, 31, 836136, tzinfo=tzutc()), '_value': 26.2, '_field': 'value', '_measurement': '°C', 'domain': 'sensor', 'entity_id': 'thermometer_hygrometer_temperature'}
# FluxRecord() table: 0, {'result': '_result', 'table': 0, '_start': datetime.datetime(2025, 6, 28, 7, 53, 11, 376450, tzinfo=tzutc()), '_stop': datetime.datetime(2025, 6, 30, 7, 53, 11, 376450, tzinfo=tzutc()), '_time': datetime.datetime(2025, 6, 29, 7, 57, 12, 301129, tzinfo=tzutc()), '_value': 26.4, '_field': 'value', '_measurement': '°C', 'domain': 'sensor', 'entity_id': 'thermometer_hygrometer_temperature'}
# FluxRecord() table: 0, {'result': '_result', 'table': 0, '_start': datetime.datetime(2025, 6, 28, 7, 53, 11, 376450, tzinfo=tzutc()), '_stop': datetime.datetime(2025, 6, 30, 7, 53, 11, 376450, tzinfo=tzutc()), '_time': datetime.datetime(2025, 6, 29, 8, 58, 55, 763728, tzinfo=tzutc()), '_value': 26.6, '_field': 'value', '_measurement': '°C', 'domain': 'sensor', 'entity_id': 'thermometer_hygrometer_temperature'}
# FluxRecord() table: 0, {'result': '_result', 'table': 0, '_start': datetime.datetime(2025, 6, 28, 7, 53, 11, 376450, tzinfo=tzutc()), '_stop': datetime.datetime(2025, 6, 30, 7, 53, 11, 376450, tzinfo=tzutc()), '_time': datetime.datetime(2025, 6, 29, 10, 2, 38, 651660, tzinfo=tzutc()), '_value': 26.8, '_field': 'value', '_measurement': '°C', 'domain': 'sensor', 'entity_id': 'thermometer_hygrometer_temperature'}
# FluxRecord() table: 0, {'result': '_result', 'table': 0, '_start': datetime.datetime(2025, 6, 28, 7, 53, 11, 376450, tzinfo=tzutc()), '_stop': datetime.datetime(2025, 6, 30, 7, 53, 11, 376450, tzinfo=tzutc()), '_time': datetime.datetime(2025, 6, 29, 11, 14, 19, 340656, tzinfo=tzutc()), '_value': 27.0, '_field': 'value', '_measurement': '°C', 'domain': 'sensor', 'entity_id': 'thermometer_hygrometer_temperature'}
# FluxRecord() table: 0, {'result': '_result', 'table': 0, '_start': datetime.datetime(2025, 6, 28, 7, 53, 11, 376450, tzinfo=tzutc()), '_stop': datetime.datetime(2025, 6, 30, 7, 53, 11, 376450, tzinfo=tzutc()), '_time': datetime.datetime(2025, 6, 29, 12, 24, 0, 566271, tzinfo=tzutc()), '_value': 27.2, '_field': 'value', '_measurement': '°C', 'domain': 'sensor', 'entity_id': 'thermometer_hygrometer_temperature'}
# FluxRecord() table: 0, {'result': '_result', 'table': 0, '_start': datetime.datetime(2025, 6, 28, 7, 53, 11, 376450, tzinfo=tzutc()), '_stop': datetime.datetime(2025, 6, 30, 7, 53, 11, 376450, tzinfo=tzutc()), '_time': datetime.datetime(2025, 6, 29, 13, 45, 38, 520598, tzinfo=tzutc()), '_value': 27.4, '_field': 'value', '_measurement': '°C', 'domain': 'sensor', 'entity_id': 'thermometer_hygrometer_temperature'}
# FluxRecord() table: 0, {'result': '_result', 'table': 0, '_start': datetime.datetime(2025, 6, 28, 7, 53, 11, 376450, tzinfo=tzutc()), '_stop': datetime.datetime(2025, 6, 30, 7, 53, 11, 376450, tzinfo=tzutc()), '_time': datetime.datetime(2025, 6, 29, 19, 59, 56, 892175, tzinfo=tzutc()), '_value': 27.2, '_field': 'value', '_measurement': '°C', 'domain': 'sensor', 'entity_id': 'thermometer_hygrometer_temperature'}
# FluxRecord() table: 0, {'result': '_result', 'table': 0, '_start': datetime.datetime(2025, 6, 28, 7, 53, 11, 376450, tzinfo=tzutc()), '_stop': datetime.datetime(2025, 6, 30, 7, 53, 11, 376450, tzinfo=tzutc()), '_time': datetime.datetime(2025, 6, 29, 21, 31, 32, 134039, tzinfo=tzutc()), '_value': 27.0, '_field': 'value', '_measurement': '°C', 'domain': 'sensor', 'entity_id': 'thermometer_hygrometer_temperature'}
# FluxRecord() table: 0, {'result': '_result', 'table': 0, '_start': datetime.datetime(2025, 6, 28, 7, 53, 11, 376450, tzinfo=tzutc()), '_stop': datetime.datetime(2025, 6, 30, 7, 53, 11, 376450, tzinfo=tzutc()), '_time': datetime.datetime(2025, 6, 29, 23, 42, 56, 709104, tzinfo=tzutc()), '_value': 26.8, '_field': 'value', '_measurement': '°C', 'domain': 'sensor', 'entity_id': 'thermometer_hygrometer_temperature'}
# FluxRecord() table: 0, {'result': '_result', 'table': 0, '_start': datetime.datetime(2025, 6, 28, 7, 53, 11, 376450, tzinfo=tzutc()), '_stop': datetime.datetime(2025, 6, 30, 7, 53, 11, 376450, tzinfo=tzutc()), '_time': datetime.datetime(2025, 6, 30, 2, 26, 12, 830236, tzinfo=tzutc()), '_value': 26.6, '_field': 'value', '_measurement': '°C', 'domain': 'sensor', 'entity_id': 'thermometer_hygrometer_temperature'}
# FluxRecord() table: 0, {'result': '_result', 'table': 0, '_start': datetime.datetime(2025, 6, 28, 7, 53, 11, 376450, tzinfo=tzutc()), '_stop': datetime.datetime(2025, 6, 30, 7, 53, 11, 376450, tzinfo=tzutc()), '_time': datetime.datetime(2025, 6, 30, 7, 44, 47, 540529, tzinfo=tzutc()), '_value': 26.4, '_field': 'value', '_measurement': '°C', 'domain': 'sensor', 'entity_id': 'thermometer_hygrometer_temperature'}
