# %%
from pathlib import Path

import numpy as np
import pandas as pd

pd.set_option('display.max_rows', 12)

# %% [markdown]
# ## Load the data

# %%
freq = "4s"
resampled_data_path = Path(f"../data/resampled-{freq}/total_power.csv")

# %%
resampled_data = pd.read_csv(resampled_data_path, index_col=0, parse_dates=True)
display(resampled_data)
resampled_data.plot()
# Out:
#                            total
# _time
# 2020-07-28 14:01:00+00:00  331.0
# 2020-07-28 14:01:04+00:00  332.0
# 2020-07-28 14:01:08+00:00  330.0
# 2020-07-28 14:01:12+00:00  332.0
# 2020-07-28 14:01:16+00:00  330.5
# ...                          ...
# 2023-01-30 13:38:00+00:00  440.0
# 2023-01-30 13:38:04+00:00  440.0
# 2023-01-30 13:38:08+00:00  442.5
# 2023-01-30 13:38:12+00:00  440.0
# 2023-01-30 13:38:16+00:00  438.0
#
# [19785260 rows x 1 columns]
# <Axes: xlabel='_time'>

# %% [markdown]
# ## Find a mapping

# %%
target_year = 2022
# resampled_data.index = pd.to_datetime(resampled_data.index, format="ISO8601")
# resampled_data

# %% [markdown]
# ### Find the days that have gaps

# %%
# count_thresh = 60
substitution_mapping = resampled_data.groupby(
    resampled_data.index.date).apply(lambda g: g.isna().any())
# substitution_mapping = substitution_mapping.where(substitution_mapping > count_thresh, True)
display(substitution_mapping)
substitution_mapping.set_index(pd.to_datetime(substitution_mapping.index, utc=True), inplace=True)
substitution_mapping.columns = ["has_gap"]
substitution_mapping["replacement"] = substitution_mapping.index
substitution_mapping["used"] = False
substitution_mapping["has_gap"].astype(int).plot()
substitution_mapping.drop(
    pd.Timestamp("2020-07-28 00:00:00+00:00", tz="UTC"),
    axis=0, errors="ignore", inplace=True
)
display(substitution_mapping)
# Out:
#             total
# 2020-07-28   True
# 2020-07-29   True
# 2020-07-30   True
# 2020-07-31   True
# 2020-08-01   True
# ...           ...
# 2023-01-26   True
# 2023-01-27   True
# 2023-01-28   True
# 2023-01-29   True
# 2023-01-30   True
#
# [917 rows x 1 columns]
#                            has_gap               replacement   used
# 2020-07-29 00:00:00+00:00     True 2020-07-29 00:00:00+00:00  False
# 2020-07-30 00:00:00+00:00     True 2020-07-30 00:00:00+00:00  False
# 2020-07-31 00:00:00+00:00     True 2020-07-31 00:00:00+00:00  False
# 2020-08-01 00:00:00+00:00     True 2020-08-01 00:00:00+00:00  False
# 2020-08-02 00:00:00+00:00     True 2020-08-02 00:00:00+00:00  False
# ...                            ...                       ...    ...
# 2023-01-26 00:00:00+00:00     True 2023-01-26 00:00:00+00:00  False
# 2023-01-27 00:00:00+00:00     True 2023-01-27 00:00:00+00:00  False
# 2023-01-28 00:00:00+00:00     True 2023-01-28 00:00:00+00:00  False
# 2023-01-29 00:00:00+00:00     True 2023-01-29 00:00:00+00:00  False
# 2023-01-30 00:00:00+00:00     True 2023-01-30 00:00:00+00:00  False
#
# [916 rows x 3 columns]

# %% [markdown]
# ### The closest substitute for each incomplete day
# The closest substitute is
# - the same weekday
# - from another year
# - that has no gaps
# - and is as close as possible in terms of time in year
#
# Caveat: The current implementation is not cyclical. Meaning that when replacing Jan 1st, Jan 10th is closer than December 31st (for better readablity, this example does not take the weekday constraint into account).

# %%
def closest_substitute(df, day):  # mind the side effect
    wd = day.weekday()
    indicator_df = df[
        (df.index.weekday == wd)  # same weekday
        & (df.index.year != day.year)  # other year
        & ~(df["has_gap"])  # no gaps
        & ~(df["used"])  # not yet used elsewhere
        ].copy()
    indicator_df["offset"] = np.abs(indicator_df.index.day_of_year - day.day_of_year)
    substitute = indicator_df.idxmin()["offset"]
    df.at[substitute, "used"] = True  # side effect
    return substitute

# %%
for idx in substitution_mapping[(substitution_mapping["has_gap"]) & (substitution_mapping.index.year == target_year)].index:
    substitution_mapping.at[idx, "replacement"] = closest_substitute(substitution_mapping, idx)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 2
#       1 for idx in substitution_mapping[(substitution_mapping["has_gap"]) & (substitution_mapping.index.year == target_year)].index:
# ----> 2     substitution_mapping.at[idx, "replacement"] = closest_substitute(substitution_mapping, idx)
#
# Cell In[6], line 10, in closest_substitute(df, day)
#       3 indicator_df = df[
#       4     (df.index.weekday == wd)  # same weekday
#       5     & (df.index.year != day.year)  # other year
#       6     & ~(df["has_gap"])  # no gaps
#       7     & ~(df["used"])  # not yet used elsewhere
#       8     ].copy()
#       9 indicator_df["offset"] = np.abs(indicator_df.index.day_of_year - day.day_of_year)
# ---> 10 substitute = indicator_df.idxmin()["offset"]
#      11 df.at[substitute, "used"] = True  # side effect
#      12 return substitute
#
# File ~/Documents/Repositories/ems-use-case-data/env/lib/python3.13/site-packages/pandas/core/frame.py:11860, in DataFrame.idxmin(self, axis, skipna, numeric_only)
#   11857 else:
#   11858     data = self
# > 11860 res = data._reduce(
#   11861     nanops.nanargmin, "argmin", axis=axis, skipna=skipna, numeric_only=False
#   11862 )
#   11863 indices = res._values
#   11864 # indices will always be np.ndarray since axis is not N
#
# File ~/Documents/Repositories/ems-use-case-data/env/lib/python3.13/site-packages/pandas/core/frame.py:11569, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   11565     df = df.T
#   11567 # After possibly _get_data and transposing, we are now in the
#   11568 #  simple case where we can use BlockManager.reduce
# > 11569 res = df._mgr.reduce(blk_func)
#   11570 out = df._constructor_from_mgr(res, axes=res.axes).iloc[0]
#   11571 if out_dtype is not None and out.dtype != "boolean":
#
# File ~/Documents/Repositories/ems-use-case-data/env/lib/python3.13/site-packages/pandas/core/internals/managers.py:1500, in BlockManager.reduce(self, func)
#    1498 res_blocks: list[Block] = []
#    1499 for blk in self.blocks:
# -> 1500     nbs = blk.reduce(func)
#    1501     res_blocks.extend(nbs)
#    1503 index = Index([None])  # placeholder
#
# File ~/Documents/Repositories/ems-use-case-data/env/lib/python3.13/site-packages/pandas/core/internals/blocks.py:406, in Block.reduce(self, func)
#     400 @final
#     401 def reduce(self, func) -> list[Block]:
#     402     # We will apply the function and reshape the result into a single-row
#     403     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     404     assert self.ndim == 2
# --> 406     result = func(self.values)
#     408     if self.values.ndim == 1:
#     409         res_values = result
#
# File ~/Documents/Repositories/ems-use-case-data/env/lib/python3.13/site-packages/pandas/core/frame.py:11470, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   11466 if isinstance(values, ExtensionArray):
#   11467     if not is_1d_only_ea_dtype(values.dtype) and not isinstance(
#   11468         self._mgr, ArrayManager
#   11469     ):
# > 11470         return values._reduce(name, axis=1, skipna=skipna, **kwds)
#   11471     has_keepdims = dtype_has_keepdims.get(values.dtype)
#   11472     if has_keepdims is None:
#
# File ~/Documents/Repositories/ems-use-case-data/env/lib/python3.13/site-packages/pandas/core/arrays/base.py:1958, in ExtensionArray._reduce(self, name, skipna, keepdims, **kwargs)
#    1953 if meth is None:
#    1954     raise TypeError(
#    1955         f"'{type(self).__name__}' with dtype {self.dtype} "
#    1956         f"does not support reduction '{name}'"
#    1957     )
# -> 1958 result = meth(skipna=skipna, **kwargs)
#    1959 if keepdims:
#    1960     result = np.array([result])
#
# File ~/Documents/Repositories/ems-use-case-data/env/lib/python3.13/site-packages/pandas/core/arrays/_mixins.py:213, in NDArrayBackedExtensionArray.argmin(self, axis, skipna)
#     211 if not skipna and self._hasna:
#     212     raise NotImplementedError
# --> 213 return nargminmax(self, "argmin", axis=axis)
#
# File ~/Documents/Repositories/ems-use-case-data/env/lib/python3.13/site-packages/pandas/core/sorting.py:481, in nargminmax(values, method, axis)
#     479             zipped = zip(arr_values.T, mask.T)
#     480         return np.array([_nanargminmax(v, m, func) for v, m in zipped])
# --> 481     return func(arr_values, axis=axis)
#     483 return _nanargminmax(arr_values, mask, func)
#
# File ~/Documents/Repositories/ems-use-case-data/env/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:1440, in argmin(a, axis, out, keepdims)
#    1351 """
#    1352 Returns the indices of the minimum values along an axis.
#    1353
#    (...)
#    1437 (2, 1, 4)
#    1438 """
#    1439 kwds = {'keepdims': keepdims} if keepdims is not np._NoValue else {}
# -> 1440 return _wrapfunc(a, 'argmin', axis=axis, out=out, **kwds)
#
# File ~/Documents/Repositories/ems-use-case-data/env/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# ValueError: attempt to get argmin of an empty sequence

# %% [markdown]
# #### The days with gaps and what they are substituted by

# %%
target_substitution_mapping = substitution_mapping[
    (substitution_mapping.index.year == target_year)
    & (substitution_mapping["has_gap"])
    ]
target_substitution_mapping
# Out:
#                            has_gap               replacement   used
# 2022-01-01 00:00:00+00:00     True 2023-01-07 00:00:00+00:00  False
# 2022-01-02 00:00:00+00:00     True 2023-01-01 00:00:00+00:00  False
# 2022-01-03 00:00:00+00:00     True 2023-01-02 00:00:00+00:00  False
# 2022-01-10 00:00:00+00:00     True 2023-01-09 00:00:00+00:00  False
# 2022-01-16 00:00:00+00:00     True 2023-01-15 00:00:00+00:00  False
# ...                            ...                       ...    ...
# 2022-11-26 00:00:00+00:00     True 2020-11-28 00:00:00+00:00  False
# 2022-11-27 00:00:00+00:00     True 2021-11-28 00:00:00+00:00  False
# 2022-11-30 00:00:00+00:00     True 2021-12-01 00:00:00+00:00  False
# 2022-12-16 00:00:00+00:00     True 2021-12-17 00:00:00+00:00  False
# 2022-12-27 00:00:00+00:00     True 2020-12-15 00:00:00+00:00  False
#
# [74 rows x 3 columns]

# %% [markdown]
# #### The days that have been used for substitution
# Visualization of the constraints being met

# %%
substitution_mapping[substitution_mapping["used"]]
# Out:
#                            has_gap               replacement  used
# 2020-08-21 00:00:00+00:00    False 2020-08-21 00:00:00+00:00  True
# 2020-08-29 00:00:00+00:00    False 2020-08-29 00:00:00+00:00  True
# 2020-09-15 00:00:00+00:00    False 2020-09-15 00:00:00+00:00  True
# 2020-11-12 00:00:00+00:00    False 2020-11-12 00:00:00+00:00  True
# 2020-11-28 00:00:00+00:00    False 2020-11-28 00:00:00+00:00  True
# ...                            ...                       ...   ...
# 2023-01-07 00:00:00+00:00    False 2023-01-07 00:00:00+00:00  True
# 2023-01-09 00:00:00+00:00    False 2023-01-09 00:00:00+00:00  True
# 2023-01-15 00:00:00+00:00    False 2023-01-15 00:00:00+00:00  True
# 2023-01-16 00:00:00+00:00    False 2023-01-16 00:00:00+00:00  True
# 2023-01-18 00:00:00+00:00    False 2023-01-18 00:00:00+00:00  True
#
# [74 rows x 3 columns]

# %% [markdown]
# ## Perform the substitution
# ### Take the target year as basis

# %%
start_date = pd.Timestamp(target_year, 1, 1)
end_date = pd.Timestamp(target_year, 12, 31, 23, 59, 59)

if target_year == 2020:
    start_date = pd.Timestamp(target_year, 7, 29)

if target_year == 2023:
    end_date = pd.Timestamp(target_year, 1, 30)

imputed_data = pd.DataFrame(
    index=pd.date_range(
        start=start_date, 
        end=end_date,
        freq='3s',
        name="time",
        tz="utc"
    ),
)

imputed_data = pd.concat([imputed_data, resampled_data.loc[imputed_data.index]], axis=1)
display(imputed_data)
imputed_data.plot()

# %% [markdown]
# ### Replace entire days according to the substitution mapping

# %%
def dayspan_after(ts):
    return slice(ts, ts + pd.Timedelta(24*60*60-1, "s"))

for gap_date, substitution in target_substitution_mapping.iterrows():
    print(gap_date)
    imputed_data.loc[dayspan_after(gap_date)] = resampled_data.loc[dayspan_after(substitution["replacement"])].values

imputed_data.plot()
# Out:
# 2020-07-29 00:00:00+00:00
# 2020-07-30 00:00:00+00:00
# 2020-07-31 00:00:00+00:00
# 2020-08-01 00:00:00+00:00
# 2020-08-02 00:00:00+00:00
# 2020-08-03 00:00:00+00:00
# 2020-08-04 00:00:00+00:00
# 2020-08-05 00:00:00+00:00
# 2020-08-06 00:00:00+00:00
# 2020-08-07 00:00:00+00:00
# 2020-08-08 00:00:00+00:00
# 2020-08-09 00:00:00+00:00
# 2020-08-10 00:00:00+00:00
# 2020-08-11 00:00:00+00:00
# 2020-08-12 00:00:00+00:00
# 2020-08-13 00:00:00+00:00
# 2020-08-18 00:00:00+00:00
# 2020-08-19 00:00:00+00:00
# 2020-08-20 00:00:00+00:00
# 2020-08-22 00:00:00+00:00
# 2020-08-23 00:00:00+00:00
# 2020-08-24 00:00:00+00:00
# 2020-08-25 00:00:00+00:00
# 2020-08-26 00:00:00+00:00
# 2020-08-27 00:00:00+00:00
# 2020-08-28 00:00:00+00:00
# 2020-09-01 00:00:00+00:00
# 2020-09-02 00:00:00+00:00
# 2020-09-03 00:00:00+00:00
# 2020-09-04 00:00:00+00:00
# 2020-09-05 00:00:00+00:00
# 2020-09-06 00:00:00+00:00
# 2020-09-07 00:00:00+00:00
# 2020-09-08 00:00:00+00:00
# 2020-09-10 00:00:00+00:00
# 2020-09-12 00:00:00+00:00
# 2020-09-14 00:00:00+00:00
# 2020-09-16 00:00:00+00:00
# 2020-09-17 00:00:00+00:00
# 2020-09-23 00:00:00+00:00
# 2020-09-27 00:00:00+00:00
# 2020-09-29 00:00:00+00:00
# 2020-09-30 00:00:00+00:00
# 2020-10-01 00:00:00+00:00
# 2020-10-09 00:00:00+00:00
# 2020-10-10 00:00:00+00:00
# 2020-10-13 00:00:00+00:00
# 2020-10-15 00:00:00+00:00
# 2020-10-16 00:00:00+00:00
# 2020-10-19 00:00:00+00:00
# 2020-10-21 00:00:00+00:00
# 2020-10-22 00:00:00+00:00
# 2020-10-23 00:00:00+00:00
# 2020-10-24 00:00:00+00:00
# 2020-10-26 00:00:00+00:00
# 2020-10-27 00:00:00+00:00
# 2020-10-28 00:00:00+00:00
# 2020-10-30 00:00:00+00:00
# 2020-11-02 00:00:00+00:00
# 2020-11-05 00:00:00+00:00
# 2020-11-08 00:00:00+00:00
# 2020-11-10 00:00:00+00:00
# 2020-11-15 00:00:00+00:00
# 2020-11-16 00:00:00+00:00
# 2020-11-19 00:00:00+00:00
# 2020-11-20 00:00:00+00:00
# 2020-11-27 00:00:00+00:00
# 2020-11-29 00:00:00+00:00
# 2020-11-30 00:00:00+00:00
# 2020-12-03 00:00:00+00:00
# 2020-12-04 00:00:00+00:00
# 2020-12-06 00:00:00+00:00
# 2020-12-07 00:00:00+00:00
# 2020-12-08 00:00:00+00:00
# 2020-12-09 00:00:00+00:00
# 2020-12-11 00:00:00+00:00
# 2020-12-14 00:00:00+00:00
# 2020-12-17 00:00:00+00:00
# 2020-12-18 00:00:00+00:00
# 2020-12-19 00:00:00+00:00
# 2020-12-20 00:00:00+00:00
# 2020-12-21 00:00:00+00:00
# 2020-12-22 00:00:00+00:00
# 2020-12-23 00:00:00+00:00
# 2020-12-24 00:00:00+00:00
# 2020-12-25 00:00:00+00:00
# 2020-12-26 00:00:00+00:00
# 2020-12-27 00:00:00+00:00
# 2020-12-28 00:00:00+00:00
# 2020-12-29 00:00:00+00:00
# 2020-12-30 00:00:00+00:00
# 2020-12-31 00:00:00+00:00
# <Axes: xlabel='time'>

# %% [markdown]
# ## Write to file, unless NaNs are remaining

# %%
if imputed_data.isna().any(axis=None):
    raise AssertionError("Imputation Failed")
else:
    imputed_data.to_csv(f"../data/resampled-{freq}/imputed_total/imputed_total-{target_year}.csv")

# %% [markdown]
# # Combine imputed yearly totals

# %%
# resampled_data_root = Path(f"../data/resampled-{freq}/")
# tables = {f.stem: f for f in Path(resampled_data_root, "imputed_total").iterdir() if f.suffix == ".csv"}

# dt_kwargs = dict(
#     index_col="time",
#     parse_dates=True,
#     date_format="ISO8601",
# )

# frames = {name: pd.read_csv(path, **dt_kwargs) for name, path in tables.items()}
# combined_imputed_total = pd.concat([frames['imputed_total-2020'], frames['imputed_total-2021'], frames['imputed_total-2022'], frames['imputed_total-2023']])
# combined_imputed_total.to_csv(Path(resampled_data_root, "imputed_total_power.csv"))

# combined_imputed_total.plot()
# Out:
# <Axes: xlabel='time'>
